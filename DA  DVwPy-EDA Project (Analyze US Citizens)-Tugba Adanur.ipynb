# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
income_df = pd.read_csv("../data/adult_eda.csv")

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
income_df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
income_df.shape
# Out:
# (32561, 15)

# %%
# Dataset information

print("US Citizens Income Levels Dataset Information:\n")
income_df.info()
# Out:
# US Citizens Income Levels Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# ...

# %%
# Check the duplicated rows

duplicate = income_df.duplicated()
duplicate.value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
# Drop the duplicated rows and check the shape of the dataset

income_df = income_df.drop_duplicates()
income_df.shape
# Out:
# (32537, 15)

# %%
# Statistical values of the dataset

income_df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
# Change the names of the columns for convenience

income_df = income_df.rename(columns={"education-num":"education_num",
                                      "marital-status":"marital_status", 
                                      "capital-gain":"capital_gain", 
                                      "capital-loss":"capital_loss", 
                                      "hours-per-week":"hours_per_week", 
                                      "native-country":"native_country"})

print("Dataset after the change of the column names:\n")
income_df.head()
# Out:
# Dataset after the change of the column names:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# ...

# %%
# Check the missing values

print("Missing value information in each column:\n")

missing_count = income_df.isnull().sum()
missing_per = income_df.isnull().sum()/income_df.shape[0]*100

missing_df = pd.concat({"missing_count": missing_count, "missing_percentage": missing_per}, axis=1)
missing_df
# Out:
# Missing value information in each column:
#                 missing_count  missing_percentage
# age                         0               0.000
# workclass                   0               0.000
# fnlwgt                      0               0.000
# education                   0               0.000
# education_num             802               2.465
# marital_status              0               0.000
# occupation                  0               0.000
# relationship             5064              15.564
# race                        0               0.000
# sex                         0               0.000
# capital_gain                0               0.000
# capital_loss                0               0.000
# hours_per_week              0               0.000
# native_country              0               0.000
# salary                      0               0.000

# %% [markdown]
# **There is a high number of missing values in the relationship column. People might prefer not to disclose their relationships in the family or hesitate to answer as "not-in-family", which might be a sensitive issue. Education column is also missing in the 2.5% of the inputs. There might be some individuals who never attended a school as there is no option given in the survey or they might hesitate to disclose their educational background.**

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
income_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
object_col = income_df.select_dtypes(include="object").columns

for col in object_col:
    print(col)
    print("--"*8)
    print(income_df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %%
# Describe the object-type columns

income_df[object_col].describe().T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
# Check if any column includes "?" as an input

income_df.apply(lambda x: x.astype("str").str.contains('\?').any())

#(income_df == "?").any(axis=0)
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %%
income_df.workclass.unique(), income_df.occupation.unique(), income_df.native_country.unique()
# Out:
# (array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#         'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#        dtype=object),
#  array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#         'Prof-specialty', 'Other-service', 'Sales', 'Craft-repair',
#         'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#         'Tech-support', '?', 'Protective-serv', 'Armed-Forces',
#         'Priv-house-serv'], dtype=object),
#  array(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
#         'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#         'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#         'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#         'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#         'China', 'Japan', 'Yugoslavia', 'Peru',
#         'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
# ...

# %% [markdown]
# **If the questions for the workclass, occupation, and native country columns are drop-down or multiple-choice style with the pre-determined answer choices, some people might not be able to fit in and might submit a question mark as their answers. There is another poosibility that workclass and occupation items are not very clear to understand for some people.**

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ### Salary Feature (Target) Analysis

# %%
# Value counts in the salary column

income_df.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
# Visualize with a countplot

fig, ax = plt.subplots(figsize=(10,6))

ax = sns.countplot(income_df["salary"])

ax.set_title("Total Number of People by Income Level", fontsize=18)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.35, p.get_height()+100))

# %%
# Percentage of number of people who make above 50K and under 50K

salary_percentages = income_df["salary"].value_counts(normalize=True)*100
salary_percentages
# Out:
# <=50K   75.907
# >50K    24.093
# Name: salary, dtype: float64

# %%
# Display the percentage distribution in the salary column

fig, ax = plt.subplots(figsize=(12,8))

colors_list = ['lightskyblue', 'gold']
explode_list = [0, 0.1]

salary_labels = income_df["salary"].value_counts(normalize=True).index

ax.pie(salary_percentages, 
       labels = salary_labels,
       labeldistance=1.1,
       textprops={'fontsize': 14},
       autopct="%.1f%%", 
       shadow=True,
       colors=colors_list,
       explode=explode_list)

ax.set_title("Percentage of Income Levels", fontsize=18)
plt.show()

# %% [markdown]
# **As displayed on the charts above, the number of people who earn 50K or less than 50K per year is way higher that the number of people who earn more than 50K per year in our sample. There are a lot more to investigate such as the educational background of our sample, number of hours worked per week, or age span to understand the results better. However, it is clearly seen that majority of our sample make 50K or less than 50K in a year.**

# %% [markdown]
# # Analyzing the Numeric Features

# %% [markdown]
# ## age

# %%
# Display the age in a box plot

fig, ax = plt.subplots(figsize=(12,8))

sns.boxplot(income_df["age"])
ax.set_title("Age Distribution", fontsize=18, color="b");

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.histplot(income_df["age"], kde=True, bins=20, color="g")
ax.set_title("Age Distribution", fontsize=18, color="b");

# %%
# The statistical values of age column

print("Statistical description of the age column:\n")
income_df["age"].describe()
# Out:
# Statistical description of the age column:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# ### Exploration of the age feature among the income levels  (<=50K vs >50K)

# %%
# Display age distribution across salary levels with a box plot and histogram

fig, ax = plt.subplots(3,1, figsize=(12, 24))
fig.suptitle("Age Distribution Across Salary-Levels", fontsize=20, color="darkblue")

sns.boxplot(data=income_df, x="salary", y="age", ax=ax[0])
sns.histplot(data=income_df, x="age", hue="salary", kde=True, bins=20, ax=ax[1])
sns.kdeplot(data=income_df, x="age", hue="salary", shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.3)
plt.show()

# %%
# Statistical values of age with respect to salary levels

print("Statistical description of age with respect to salary-levels:")
income_df.groupby("salary")['age'].describe()
# Out:
# Statistical description of age with respect to salary-levels:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# ### Conclusions:
#
# **First, the characteristics of the age column was investigated. Here are the findings:**
# - There are some extreme values around/between the ages of 78-90.
# - Mean is 38, and it is observed that majority of the people are between 28 and 48 years old.
# - The age data is right skewed, which means that our sample is a young population as expected. Most people after the age of 65 will be retired and will no longer work.
#
# **Then, the age component was explored through the salary levels (<=50K and >50K) was explored:**
# - Visuals revealed that the people who make less than or equal to 50K are a younger population than the people who make above 50K per year.
# - It is hard to make a comment such that older people always earn more compared to the younger people or visa versa. Because we have extreme values showing that there are people between 80-90 years old and make less than 50K, and there are people who are below 30 years old and make more than 50K.
# - When we consider histogram and kde plot, it is realized that both the age feature of both populations (who make <=50K and >50K) are right skewed while the population who make >50K is closer to a normal distribution.
# - It is expected that the population who make less than 50K shows a stronger right-skewed graph. Younger people are less experienced or new graduates. As a result, they will earn less as seen on the graphs.

# %% [markdown]
# ## fnlwgt - final weight (the number of people the census believes the entry represents)

# %%
income_df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Check the boxplot for extreme values

fig, ax = plt.subplots(3,1, figsize=(12,16))
fig.suptitle("Fnlwgt Distribution", fontsize=20, color="darkblue")

sns.boxplot(data=income_df, x='fnlwgt', ax=ax[0])
sns.histplot(data=income_df, x='fnlwgt', bins=50, kde=True, ax=ax[1])
sns.kdeplot(data=income_df, x='fnlwgt', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of fnlwgt

income_df.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# ###  Exploration of the fnlwgt column across the salary-levels.

# %%
fig, ax = plt.subplots(3,1, figsize=(12,16))
fig.suptitle("Fnlwgt Distribution By Salary Levels", fontsize=20, color='darkblue')

sns.boxplot(data=income_df, x='salary', y='fnlwgt', ax=ax[0])
sns.histplot(data=income_df, x='fnlwgt', hue='salary', bins=50, ax=ax[1])
sns.kdeplot(data=income_df, x='fnlwgt', hue='salary', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of the fnlwgt column with respect to salary-levels

print("Statistical description of the fnlwgt column with respect to salary-levels: ")
income_df.groupby("salary")["fnlwgt"].describe()
# Out:
# Statistical description of the fnlwgt column with respect to salary-levels:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# not very affected by salary. medianlar hemen hemen ayni iki salary leveldedeIT is more comprehensive.

# %% [markdown]
# ## capital_gain

# %%
# Check the boxplot for extreme values

fig, ax = plt.subplots(3,1, figsize=(12,16))
fig.suptitle("Capital Gain Distribution", fontsize=20, color="darkblue")

sns.boxplot(data=income_df, x='capital_gain', ax=ax[0])
sns.histplot(data=income_df, x='capital_gain', bins=50, ax=ax[1])
sns.kdeplot(data=income_df, x='capital_gain', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of capital gain column

income_df.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %%
# Display capital gain distribution across salary levels with a box plot and histogram

fig, ax = plt.subplots(3,1, figsize=(10,20))
fig.suptitle("Capital Gain Distribution By Salary Levels", fontsize=20, color='darkblue')

sns.boxplot(data=income_df, x='salary', y='capital_gain', ax=ax[0])
sns.histplot(data=income_df, x='capital_gain', hue='salary', bins=50, ax=ax[1])
sns.kdeplot(data=income_df, x='capital_gain', hue='salary', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# A closer look at the capital gain distribution across salary levels with a box plot and histogram
# There are too many zeroes as inputs in capital gain column and the case in the absence of zeroes must be investigated too

nonzero_capital_gain_df = income_df.loc[income_df["capital_gain"] != 0]

fig, ax = plt.subplots(4,1, figsize=(10,20))
fig.suptitle("A Closer Look at Capital Gain Distribution By Salary Levels", fontsize=20, color='darkblue')

ax[0].set_ylim(0, 30000)
ax[1].set_ylim(0, 30000)
ax[2].set_xlim(-100,10000)
ax[3].set_xlim(-10000,20000)
ax[3].set_ylim(0, .0001)

sns.boxplot(data=income_df, x='salary', y='capital_gain', ax=ax[0])
sns.boxplot(data=nonzero_capital_gain_df, x='salary', y='capital_gain', ax=ax[1])
sns.histplot(data=income_df, x='capital_gain', hue='salary', bins=50, ax=ax[2])
sns.kdeplot(data=income_df, x='capital_gain', hue='salary', shade=True, ax=ax[3])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of the capital gain column with respect to salary-levels

print("Statistical description of the capital gain column with respect to salary-levels: ")
income_df.groupby("salary")["capital_gain"].describe()
# Out:
# Statistical description of the capital gain column with respect to salary-levels:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %%
print("Statistical description of the nonzero values in the capital gain column with respect to salary-levels: ")

nonzero_capital_gain_df.groupby("salary")["capital_gain"].describe()
# Out:
# Statistical description of the nonzero values in the capital gain column with respect to salary-levels:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# **Capital gain is usually known as the profits made from the sale of real estate, investments, and personal property.**
#
# **The dataset indicates the following findings when all rows are included:**
# - The average capital gain earned by the people who make above 50K is almost 27 times larger than the capital gain earned by the people who make 50K or below 50K.
# - There are extreme values such as a capital gain of 41K made by <=50K population or 99999K made by >50K population and they affect the average values.
# - The capital gain values made by the people in the ">50K income-level" vary way more than the values made by the people in the "<=50K income-level". The latter clustered around "0" as the former varies mostly between 0 and 20K.
# - When the min, median, and interquartile ranges are checked, it is realized that a lot of values of zero exist in the capital gain column. That's why it might be better to check the statistical description of the capital gain column excluding the rows with zero values.
#
# **The dataset indicates the following findings when the rows with zero values are excluded:**
# - The average capital gain earned by the people who make above 50K is almost 5 times larger than the capital gain earned by the people who make 50K or below 50K. It has a sharp decrease when compared to the output above.
# - The standard deviation increases in both salary-levels, which shows that the varieties of capital gain values increase since most of the values were 0's in the previous scenerio.
# - The median and IQRs vary a lot between two salary levels. While the capital gain of "<=50K population" is mostly clustered below 5K, the capital gain of ">50K population" varies mostly between 7K-15K.
#
# **Final Thoughts:**
#
# People who earn more are tend to make investments more than the people who earn less. However, almost 79% of the people who earn >50K reported "0" as their capital gain. This can be the starter of another story about why people don't/can't invest.

# %% [markdown]
# ## capital_loss

# %%
# Check the boxplot for extreme values

fig, ax = plt.subplots(3,1, figsize=(12,16))
fig.suptitle("Capital Loss Distribution", fontsize=20, color="darkblue")

sns.boxplot(data=income_df, x='capital_loss', ax=ax[0])
sns.histplot(data=income_df, x='capital_loss', bins=20, ax=ax[1])
sns.kdeplot(data=income_df, x='capital_loss', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of capital loss

income_df.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %%
# Display age distribution across salary levels with a box plot and histogram

fig, ax = plt.subplots(3,1, figsize=(12,16))
fig.suptitle("Capital Loss Distribution By Salary Levels", fontsize=20, color='darkblue')

sns.boxplot(data=income_df, x='salary' ,y='capital_loss', ax=ax[0])
sns.histplot(data=income_df, x='capital_loss', hue='salary', bins=50, ax=ax[1])
sns.kdeplot(data=income_df, x='capital_loss', hue='salary', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# A closer look at the capital loss distribution across salary levels with a box plot and histogram
# There are too many zeroes as inputs in capital loss column and the case in the absence of zeroes must be investigated too

nonzero_capital_loss_df = income_df.loc[income_df["capital_loss"] != 0]

fig, ax = plt.subplots(4,1, figsize=(10,20))
fig.suptitle("A Closer Look at Capital Loss Distribution By Salary Levels", fontsize=20, color='darkblue')

ax[0].set_ylim(0, 5000)
ax[1].set_ylim(0, 5000)
ax[2].set_xlim(-100,4000)
ax[3].set_xlim(-1000,4000)
ax[3].set_ylim(0, .001)

sns.boxplot(data=income_df, x='salary', y='capital_loss', ax=ax[0])
sns.boxplot(data=nonzero_capital_loss_df, x='salary', y='capital_loss', ax=ax[1])
sns.histplot(data=income_df, x='capital_loss', hue='salary', bins=50, ax=ax[2])
sns.kdeplot(data=income_df, x='capital_loss', hue='salary', shade=True, ax=ax[3])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of the capital loss column with respect to salary-levels

print("Statistical description of the capital loss column with respect to salary-levels: ")
income_df.groupby("salary")["capital_loss"].describe()
# Out:
# Statistical description of the capital loss column with respect to salary-levels:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %%
# Statistical description of the capital loss column with respect to salary-levels

print("Statistical description of the nonzero values in the capital loss column with respect to salary-levels: ")
nonzero_capital_loss_df.groupby("salary")["capital_loss"].describe()
# Out:
# Statistical description of the nonzero values in the capital loss column with respect to salary-levels:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# **A capital loss is considered to sell an investment for less than the original purchase price.**
#
# **Here are the findings from the dataset:**
# - Unlike the capital gain, we recognize a similar patterns for both salary-levels populations in the capital loss data.
# - The graphs -boxplots and histograms- show similar distributions among the people who make <=50K and the people who make >50K. Both are close to a normal distribution and most of the values are clustered around "0". It leaded us again to consider the capital loss column with nonzero values to better understand the data.
# - When "0" values are eliminated, it is realized that the pattern of the data in both salary levels get closer to each other. The statistical description of the capital loss data support our claim with the close mean, median, and IQRs.

# %% [markdown]
# ## hours_per_week

# %%
# Check the boxplot for extreme values

fig, ax = plt.subplots(3,1, figsize=(12,20))
fig.suptitle("Number of Working Hours Distribution", fontsize=20, color="darkblue")

sns.set(font_scale=1.5)
sns.boxplot(data=income_df, x='hours_per_week', ax=ax[0])
sns.histplot(data=income_df, x='hours_per_week', bins=20, ax=ax[1])
sns.kdeplot(data=income_df, x='hours_per_week', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of the number of the working hours

income_df.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %%
# Display hours_per_week distribution across salary levels with a box plot and histogram

fig, ax = plt.subplots(3,1, figsize=(12,20))
fig.suptitle("Number of Working Hours Distribution By Salary Levels", fontsize=20, color='darkblue')

sns.boxplot(data=income_df, x="salary" ,y='hours_per_week', ax=ax[0])
sns.histplot(data=income_df, x='hours_per_week', hue='salary', bins=20, ax=ax[1])
sns.kdeplot(data=income_df, x='hours_per_week', hue='salary', shade=True, ax=ax[2])

plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
# Statistical description of the hours_per_week column with respect to salary-levels

print("Statistical description of the hours_per_week column with respect to salary-levels: ")
income_df.groupby("salary")["hours_per_week"].describe()
# Out:
# Statistical description of the hours_per_week column with respect to salary-levels:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# - We don't recognize a distinguishable difference between two salary levels in terms of the number of working hours. Both salary-level graphs indicate that the number of hour values clustered at 40 hours as expected. Most of the full time employees work 8 hours per day. Since the number of working hours is standardized, it doesn't change much across the salary levels.
# - However, it is observed that the "<=50K population" data shows a normal distribution while ">50K population" data is slightly right-skewed. The statistical measurements support the visuals with closer mean & median values in the former while a higher mean compared to median in the latter.

# %% [markdown]
# ## Numeric features by target feature (salary)

# %%
#numeric_columns = ["age", "fnlwgt", "education_num", "capital_gain", "capital_loss", "hours_per_week"]

# %%
sns.pairplot(income_df, hue="salary", corner=True, palette="viridis");

# %% [markdown]
# # Analyzing the Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Are there any similarities between the education and education_num features?**

# %%
# Value counts in the education feature

income_df["education"].value_counts(dropna=False)
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# Value counts in the education_num feature

income_df["education_num"].value_counts(dropna=False)
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
# Merge two series and count the number people in each group

income_df.groupby(["education", "education_num"], dropna=False)[["education_num"]].count()
# Out:
#                             education_num
# education    education_num
# 10th         6.000                    916
#              NaN                        0
# 11th         7.000                   1146
#              NaN                        0
# 12th         8.000                    424
#              NaN                        0
# 1st-4th      2.000                    159
#              NaN                        0
# 5th-6th      3.000                    329
#              NaN                        0
# 7th-8th      4.000                    630
#              NaN                        0
# 9th          5.000                    503
#              NaN                        0
# Assoc-acdm   12.000                  1044
#              NaN                        0
# Assoc-voc    11.000                  1343
#              NaN                        0
# Bachelors    13.000                  5245
#              NaN                        0
# Doctorate    16.000                   405
# ...

# %%
# Visualization of education and education_num features

fig, ax = plt.subplots(2, 1, figsize=(8, 12))

sns.countplot(income_df["education"], ax=ax[0])
sns.countplot(income_df["education_num"], ax=ax[1])

ax[0].tick_params(axis='x', rotation=90)

plt.subplots_adjust(hspace=0.6)

# %%
# Visualization of education feature

education_count = income_df["education"].value_counts().index
education_num_count = income_df["education_num"].value_counts().index

fig, ax = plt.subplots(2, 1, figsize=(8, 12))

sns.countplot(income_df["education"], order=education_count, ax=ax[0])
sns.countplot(income_df["education_num"], order=education_num_count, ax=ax[1])

ax[0].tick_params(axis='x', rotation=90)

plt.subplots_adjust(hspace=0.6)

# %% [markdown]
# **The pattern of the counts in both features are almost equivalent. It is realized that "9.0" represent "HS-Grad", "10.0" represents "Some-college", "1.0" represents "Preschool" and so on. There are slight differences between the counts. It might be caused by the human errors during the survey.**

# %% [markdown]
# ### education and education_num features by salary

# %%
income_df.groupby("education")["salary"].value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
# Visualize the number of people in each education level by salary

fig, ax = plt.subplots()

sns.set(font_scale=1)
sns.countplot(data=income_df, x="education", hue="salary")

plt.xticks(rotation=90)
plt.legend(loc='upper right');

# %%
income_df.groupby("education_num")["salary"].value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
# Visualize the number of people in each education-num level by salary

fig, ax = plt.subplots()

sns.countplot(data=income_df, x="education_num", hue="salary")

plt.legend(loc='upper right');

# %%
# Visualize the boxplot of "education_num" feature by "salary" levels

fig, ax = plt.subplots()

sns.boxplot(data=income_df, x="salary", y="education_num");

# %% [markdown]
# **Decreasing the number of categories in "education" feature as low, medium, and high level and creating a new feature with this new categorical data would be helpful to interpret the data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
income_df["education"].apply(mapping_education).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
income_df["education_summary"] = income_df["education"].apply(mapping_education)
income_df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Visualize the count of person in each categories for these new education levels (high, medium, low)

fig, ax = plt.subplots()

sns.countplot(income_df["education_summary"]);

# %%
# The count of person in each "salary" levels by these new education levels(high, medium, low)

income_df.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# Visualize the count of person in each "salary" levels by these new education levels(high, medium, low) with countplot

fig, ax = plt.subplots()

sns.countplot(data=income_df, x="education_summary", hue="salary")
ax.set_title("Salary by Education Levels", fontsize=16);

# %%
# The percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) 

salary_percentages = income_df.groupby("education_summary")["salary"].value_counts(normalize=True) * 100
salary_percentages
# Out:
# education_summary   salary
# high_level_grade    <=50K    51.525
#                     >50K     48.475
# low_level_grade     <=50K    94.256
#                     >50K      5.744
# medium_level_grade  <=50K    81.775
#                     >50K     18.225
# Name: salary, dtype: float64

# %%
# Visualize the salary percentages by education levels

fig = plt.figure(figsize=(12,8))

education_new_levels = ["high_level_grade", "low_level_grade", "medium_level_grade"]
colors_list_1 = ['lightpink', 'lightskyblue']

a=1
b=3
c=1

for i in education_new_levels:
    plt.subplot(a, b, c)
    plt.title(i)
    plt.ylabel("salary")
    plt.pie(salary_percentages[i], 
       labels = my_labels,
       labeldistance=1.1,
       textprops={'fontsize': 11},
       autopct="%.2f%%", 
       shadow=True,
       colors=colors_list_1)
    c = c + 1
    
plt.tight_layout()
plt.show()

# %%
# The count of person in each these new education levels(high, medium, low) by "salary" levels

income_df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Visualize he count of person in each these new education levels(high, medium, low) by "salary" levels with countplot

fig,ax = plt.subplots()

sns.countplot(data=income_df, x="salary", hue="education_summary");

# %%
# The percentage distribution of person in each these new education levels by "salary" levels 

education_summary_percentages = income_df.groupby("salary")["education_summary"].value_counts(normalize=True)
education_summary_percentages
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
# Visualize the percentages with pie plot

fig, ax = plt.subplots(1,2, figsize=(16,10))

colors_list_2 = ['lightpink', 'lightskyblue', 'lightgreen']
below_50_labels=["(<=50K, medium_level_grade)", "(<=50K, high_level_grade)" , "(<=50K, low_level_grade)"]
above_50_labels=["(>50K, high_level_grade)", "(>50K, medium_level_grade)" , "(>50K, low_level_grade)"]

ax[0].set_title("<=50K", fontsize=14)
ax[1].set_title(">50K", fontsize=14)

ax[0].set_ylabel("education_summary")
ax[1].set_ylabel("education_summary")

ax[0].pie(education_summary_percentages["<=50K"], 
       labels = below_50_labels,
       labeldistance=1.1,
       textprops={'fontsize': 12},
       autopct="%.2f%%", 
       shadow=True,
       colors=colors_list_2)

ax[1].pie(education_summary_percentages[">50K"], 
       labels = above_50_labels,
       labeldistance=1.1,
       textprops={'fontsize': 12},
       autopct="%.2f%%", 
       shadow=True,
       colors=colors_list_2)
                                                            
            
plt.subplots_adjust(wspace=0.8)            
plt.show()

# %%
# Create a dataframe of education level percentages by salary levels

df_perc_ed = pd.DataFrame(income_df.groupby("salary")["education_summary"].value_counts(normalize=True))
df_perc_ed.columns = ["percentage"]
df_perc_ed.reset_index(inplace=True)
df_perc_ed.sort_values(by=["education_summary"])
# Out:
#   salary   education_summary  percentage
# 1  <=50K    high_level_grade       0.168
# 3   >50K    high_level_grade       0.499
# 2  <=50K     low_level_grade       0.162
# 5   >50K     low_level_grade       0.031
# 0  <=50K  medium_level_grade       0.670
# 4   >50K  medium_level_grade       0.470

# %%
# Visualize the education level percentages by salary

fig, ax = plt.subplots(1, 2, figsize=(12,8))


ed_level_labels = ["high", "low", "medium"]
colors_list_2 = ['lightpink', 'lightskyblue', 'lightgreen']

ax[0].pie(x = df_perc_ed.loc[df_perc_ed["salary"] == "<=50K"]["percentage"],
         labels = ed_level_labels,
         labeldistance=1.1,
         textprops={'fontsize': 12},
         autopct="%.2f%%", 
         shadow=True,
         colors=colors_list_2)

ax[1].pie(x = df_perc_ed.loc[df_perc_ed["salary"] == ">50K"]["percentage"],
         labels = ed_level_labels,
         labeldistance=1.1,
         textprops={'fontsize': 12},
         autopct="%.2f%%", 
         shadow=True,
         colors=colors_list_2)                           ###### WORK ON THE LABELS LATER

ax[0].set_title("<=50K", fontsize=16)
ax[1].set_title(">50K", fontsize=16)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# **TO BE FILLED OUT**

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Unique values in both features will be compared to check for any similarities.**

# %%
income_df["marital_status"].value_counts(dropna=False)
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
income_df["relationship"].value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill the missing values with "Unknown" in the column of "relationship"

income_df["relationship"] = income_df["relationship"].fillna('Unknown')
income_df["relationship"].value_counts()
# Out:
# Husband           13187
# Not-in-family      8292
# Unknown            5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Marital status counts by relationship

income_df.groupby("relationship")["marital_status"].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
# ...

# %% [markdown]
# ### Comments about the findings above: TO BE FILLED OUT

# %%
# Visualize the count of person in each marital status categories

sns.countplot(income_df["marital_status"])

plt.title("Number of people in each marital status category", fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %%
# The count of person in each "salary" levels by categories 

income_df.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Visualize the data above with countplot

sns.countplot(data=income_df, x="marital_status", hue="salary")

plt.title("Number of people in each salary level by marital status", fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **The number of categories in "marital_status" feature will be re-organized as married and unmarried for more investigation. The new feature will be added to the dataset as a new categorical data.**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
income_df["marital_status"].apply(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
income_df["marital_status_summary"] = income_df["marital_status"].apply(lambda x: mapping_marital_status(x))
income_df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Visualize the count of person in each categories for these new marital status (married, unmarried)


sns.countplot(income_df["marital_status_summary"])

plt.title("Marital Status Counts", fontsize=16);

# %%
# The count of person in each "salary" levels by these new marital status (married, unmarried)

income_df.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Visualize the data above with countplot

sns.countplot(data=income_df, x="marital_status_summary", hue="salary")

plt.title("Salary Levels by Marital Status Summary", fontsize=16)
plt.show()

# %%
# Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) 

salary_marital_percentages = income_df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
salary_marital_percentages
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
# Visualize the data above with pie plot

fig = plt.figure(figsize=(12,8))

colors_list_2 = ['lightpink', 'lightskyblue']
salary_labels = ["<=50K", ">50K"]
marital_status_sum = ["married", "unmarried"]

a=1
b=2
c=1

for i in marital_status_sum:
    plt.subplot(a, b, c)
    plt.title(i)
    plt.ylabel("salary")
    plt.pie(salary_marital_percentages[i], 
       labels = salary_labels,
       labeldistance=1.1,
       textprops={'fontsize': 11},
       autopct="%.2f%%", 
       colors=colors_list_2)
    c = c + 1
    
plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
# Check the count of person in each these new marital status (married, unmarried) by "salary" levels 

income_df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Visualize it with countplot

sns.countplot(data=income_df, x="salary", hue="marital_status_summary")
plt.title("Salary by Marital Status", fontsize=16);

# %%
# The percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels

marital_summary_percentages = income_df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
marital_summary_percentages
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
df_perc_marital = pd.DataFrame(income_df.groupby("salary")["marital_status_summary"].value_counts(normalize=True))
df_perc_marital.columns = ["percentage"]
df_perc_marital.reset_index(inplace=True)
df_perc_marital
# Out:
#   salary marital_status_summary  percentage
# 0  <=50K              unmarried       0.649
# 1  <=50K                married       0.351
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %%
# Visualize the percentages with pie plot

salary_levels = ["<=50K", ">50K"]

fig = plt.figure(figsize=(12,8))

colors_list_2 = ['lightskyblue', 'lightpink']
my_labels_mar = ['unmarried', 'married']

a=1
b=2
c=1

for i in salary_levels:
    plt.subplot(a, b, c)
    plt.title(i)
    plt.ylabel("percentage")
    plt.pie(marital_summary_percentages[i], 
       labels = my_labels_mar,
       labeldistance=1.1,
       textprops={'fontsize': 11},
       autopct="%.2f%%",                             ##### WORK ON THE LABELS  -YOU NEED TO USE THE DATAFRAME
       colors=colors_list_2)
    c = c + 1
    
plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# **to be filled out**

# %% [markdown]
# ## workclass

# %%
# Count of people in each category

income_df["workclass"].value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
income_df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Visualize the count of people in each category

sns.countplot(income_df["workclass"])
plt.xticks(rotation=90)
plt.title("Number of People in Each Workclass", fontsize=16);

# %%
# Replace "?" values with "Unknown"

income_df["workclass"].replace("?", "Unknown", inplace=True)
income_df["workclass"].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Count of people in each "salary" levels by "workclass" feature 

income_df.groupby(["workclass", "salary"])["salary"].count()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      <=50K       494
#                   >50K        622
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Countplot the count of people in each "salary" levels by "workclass" feature

sns.countplot(data=income_df, x="workclass", hue="salary")
plt.title("Salary Distribution by Workclass", fontsize=16)
plt.xticks(rotation=90);

# %%
# The percentage distribution of person in each "salary" levels by each workclass groups 

income_df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
df_perc_workclass = pd.DataFrame(income_df.groupby("workclass")["salary"].value_counts(normalize=True))
df_perc_workclass.columns = ["percentage"]
df_perc_workclass.reset_index(inplace=True)
df_perc_workclass
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
# Barplot of the percentage distribution of person in each "salary" levels by each workclass groups

fig, ax = plt.subplots()

sns.barplot(data=df_perc_workclass, x="workclass", y="percentage", hue="salary")
plt.title("Salary Distribution by Workclass", fontsize=16)
plt.xticks(rotation=90)

for p in ax.patches:
    ax.annotate((round(p.get_height(),2)), (p.get_x(), p.get_height()+0.01))

# %%
# The count of person in each workclass groups by "salary" levels

income_df.groupby("salary")["workclass"].value_counts(dropna=False)
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# The countplot of person in each workclass groups by "salary" levels

sns.countplot(data=income_df, x="salary", hue="workclass")
plt.title("Number of People in Each Workclass by Salary", fontsize=16)
plt.legend(loc="upper right");

# %%
# Check the percentage distribution of person in each workclass groups by "salary" levels

income_df.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
df_salary_work = pd.DataFrame(income_df.groupby("salary")["workclass"].value_counts(normalize=True))
df_salary_work.columns = ["percentage"]
df_salary_work.reset_index(inplace=True)
df_salary_work
# Out:
#    salary         workclass  percentage
# 0   <=50K           Private       0.717
# 1   <=50K  Self-emp-not-inc       0.074
# 2   <=50K           Unknown       0.067
# 3   <=50K         Local-gov       0.060
# 4   <=50K         State-gov       0.038
# 5   <=50K       Federal-gov       0.024
# 6   <=50K      Self-emp-inc       0.020
# 7   <=50K       Without-pay       0.001
# 8   <=50K      Never-worked       0.000
# 9    >50K           Private       0.633
# 10   >50K  Self-emp-not-inc       0.092
# 11   >50K      Self-emp-inc       0.079
# 12   >50K         Local-gov       0.079
# 13   >50K       Federal-gov       0.047
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %%
# Countplot of the percentage distribution of person in each workclass groups by "salary" levels

fig, ax = plt.subplots(figsize=(16,8))
sns.barplot(data=df_salary_work, x="salary", y="percentage", hue="workclass")
plt.title("Percentage of People in Each Workclass by Salary", fontsize=16)
plt.legend(loc="upper right")

for p in ax.patches:
    ax.annotate((round(p.get_height(),3)), (p.get_x()+0.02, p.get_height()+0.01), size=9)

# %% [markdown]
# ### Conclusions::

# %% [markdown]
# ##  occupation

# %%
# The count of person in each categories

income_df["occupation"].value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Replace "?" value with "Unknown"

income_df["occupation"].replace("?", "Unknown", inplace=True)
income_df["occupation"].value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Countplot of person in each categories

sns.countplot(income_df["occupation"])
plt.title("Number of People in Each Occupation", fontsize=16)
plt.xticks(rotation=90);

# %%
# The count of person in each "salary" levels by occupation groups

income_df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
# Countplot of the count of person in each "salary" levels by occupation groups

sns.countplot(data=income_df, x="occupation", hue="salary")
plt.title("Number of People in Each Salary Level by Occupation", fontsize=16)
plt.xticks(rotation=90);

# %%
# The percentage distribution of person in each "salary" levels by each occupation group

income_df.groupby("occupation")["salary"].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
df_ocpt_salary = pd.DataFrame(income_df.groupby("occupation")["salary"].value_counts(normalize=True))
df_ocpt_salary.columns = ["percentage"]
df_ocpt_salary.reset_index(inplace=True)
df_ocpt_salary
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
# Barplot of the percentage distribution of person in each "salary" levels by each occupation group

fig, ax = plt.subplots(figsize=(16, 8))
sns.barplot(data=df_ocpt_salary, x="occupation", y="percentage", hue="salary")
plt.title("Percentage of People in Each Salary Level by Occupation", fontsize=16)
plt.legend(loc="upper right")
plt.xticks(rotation=90)

for p in ax.patches:
    ax.annotate((round(p.get_height(),2)), (p.get_x()+0.025, p.get_height()+0.01), size=9)

# %%
# The count of person in each occupation groups by "salary" levels

income_df.groupby("salary")["occupation"].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
# Barplot of the count of person in each occupation groups by "salary" levels

fig = plt.subplots(figsize=(16, 8))
sns.countplot(data=income_df, x="salary", hue="occupation")
plt.title("Number of People in Each Occupation by Salary Levels", fontsize=16);

# %%
#  The percentage distribution of person in each occupation groups by "salary" levels

income_df.groupby("salary")["occupation"].value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
df_salary_ocpt = pd.DataFrame(income_df.groupby("salary")["occupation"].value_counts(normalize=True))
df_salary_ocpt.columns = ["percentage"]
df_salary_ocpt.reset_index(inplace=True)
df_salary_ocpt
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K            Unknown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# ...

# %%
# Barplot of the percentage distribution of person in each "occupation" by each salary levels

fig, ax = plt.subplots(figsize=(16, 8))
sns.barplot(data=df_salary_ocpt, x="salary", y="percentage", hue="occupation")
plt.title("Percentage of People in Each Occupation by Salary Levels", fontsize=16)
plt.legend(loc="upper right")
plt.xticks(rotation=90)

for p in ax.patches:
    ax.annotate((round(p.get_height(),2)), (p.get_x()+0.01, p.get_height()+0.003), size=9)

# %%
# The count of person in each categories

income_df["occupation"].value_counts(dropna=False)

# Replace "?" value with "Unknown"

income_df["occupation"].replace("?", "Unknown", inplace=True)
income_df["occupation"].value_counts()

# Countplot of person in each categories

sns.countplot(income_df["occupation"])
plt.title("Number of People in Each Occupation", fontsize=16)
plt.xticks(rotation=90);


# The count of person in each "salary" levels by occupation groups

income_df.groupby("occupation")["salary"].value_counts()

# Countplot of the count of person in each "salary" levels by occupation groups

sns.countplot(data=income_df, x="occupation", hue="salary")
plt.title("Number of People in Each Salary Level by Occupation", fontsize=16)
plt.xticks(rotation=90);

# DaDataframe

df_ocpt_salary = pd.DataFrame(income_df.groupby("occupation")["salary"].value_counts(normalize=True))
df_ocpt_salary.columns = ["percentage"]
df_ocpt_salary.reset_index(inplace=True)
df_ocpt_salary


# Barplot of the percentage distribution of person in each "salary" levels by each occupation group

fig, ax = plt.subplots(figsize=(16, 8))
sns.barplot(data=df_ocpt_salary, x="occupation", y="percentage", hue="salary")
plt.title("Percentage of People in Each Salary Level by Occupation", fontsize=16)
plt.legend(loc="upper right")
plt.xticks(rotation=90)

for p in ax.patches:
    ax.annotate((round(p.get_height(),2)), (p.get_x()+0.025, p.get_height()+0.01), size=9)

    
# The count of person in each occupation groups by "salary" levels

income_df.groupby("salary")["occupation"].value_counts()

# Barplot of the count of person in each occupation groups by "salary" levels

fig = plt.subplots(figsize=(16, 8))
sns.countplot(data=income_df, x="salary", hue="occupation")
plt.title("Number of People in Each Occupation by Salary Levels", fontsize=16);

#  The percentage distribution of person in each occupation groups by "salary" levels

income_df.groupby("salary")["occupation"].value_counts(normalize=True)

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# ## race

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
